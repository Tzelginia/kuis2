# %% [markdown]
# NAMA : TZELGINIA NOER CAHYANI
#
# KELAS : TI 3F
#
# NIM : 2041720048
#
# NO.ABSEN : 20
#
# MATA KULIAH : MACHINE LEARNING (KUIS 2)

# %%
# import library
import pandas as pd
import numpy as np

# %%
# Membaca dan Cek Data
df = pd.read_csv('dataset_quiz.csv')

df.head()
# Out:
#    id_ketua  id_anggota1  id_anggota2  id_anggota3  id_anggota4  id_anggota5  \
# 0    7206.0       7214.0       6211.0       8602.0       7801.0          NaN
# 1    7214.0       7109.0       8402.0       7903.0       9202.0          NaN
# 2    5911.0       8201.0       8701.0       9101.0       9003.0          NaN
# 3    8402.0       7702.0       8602.0       8903.0       8903.0          NaN
# 4    8201.0       8305.0       5911.0       5903.0       8402.0          NaN
#
#   keterlibatan_vltr  jml_vltr_terlibat  tahun    skema luaran_hki  \
# 0             TIDAK                  0   2019  REGULER  TIDAK ADA
# 1             TIDAK                  0   2019  REGULER  TIDAK ADA
# 2             TIDAK                  0   2019  REGULER  TIDAK ADA
# 3             TIDAK                  0   2019  REGULER  TIDAK ADA
# 4             TIDAK                  0   2019  REGULER  TIDAK ADA
#
#   jenis_luaran_hki potensi_hki luaran_lain jenis_luaran_lain  \
# 0        TIDAK ADA       TIDAK   TIDAK ADA         TIDAK ADA
# 1        TIDAK ADA       TIDAK   TIDAK ADA         TIDAK ADA
# 2        TIDAK ADA       TIDAK   TIDAK ADA         TIDAK ADA
# 3        TIDAK ADA       TIDAK   TIDAK ADA         TIDAK ADA
# 4        TIDAK ADA       TIDAK   TIDAK ADA         TIDAK ADA
#
#   status_luaran_lain
# 0          TIDAK ADA
# 1          TIDAK ADA
# 2          TIDAK ADA
# 3          TIDAK ADA
# 4          TIDAK ADA

# %%
# Cek data yang kosong
df.isna().sum()
# Out:
# id_ketua               3
# id_anggota1            5
# id_anggota2            4
# id_anggota3            3
# id_anggota4           13
# id_anggota5           84
# keterlibatan_vltr      0
# jml_vltr_terlibat      0
# tahun                  0
# skema                  0
# luaran_hki             0
# jenis_luaran_hki       0
# potensi_hki            0
# luaran_lain            0
# jenis_luaran_lain      0
# status_luaran_lain     0
# dtype: int64

# %%
# Menghilangkan data null
df.drop('id_anggota5', axis=1, inplace=True)

modus_ketua = df['id_ketua'].mode()[0]
df['id_ketua'] = df['id_ketua'].fillna(modus_ketua)

modus_anggota1 = df['id_anggota1'].mode()[0]
df['id_anggota1'] = df['id_anggota1'].fillna(modus_anggota1)

modus_anggota2 = df['id_anggota2'].mode()[0]
df['id_anggota2'] = df['id_anggota2'].fillna(modus_anggota2)

modus_anggota3 = df['id_anggota3'].mode()[0]
df['id_anggota3'] = df['id_anggota3'].fillna(modus_anggota3)

modus_anggota4 = df['id_anggota4'].mode()[0]
df['id_anggota4'] = df['id_anggota4'].fillna(modus_anggota4)
# Cek Data
df.head()
# Out:
#    id_ketua  id_anggota1  id_anggota2  id_anggota3  id_anggota4  \
# 0    7206.0       7214.0       6211.0       8602.0       7801.0
# 1    7214.0       7109.0       8402.0       7903.0       9202.0
# 2    5911.0       8201.0       8701.0       9101.0       9003.0
# 3    8402.0       7702.0       8602.0       8903.0       8903.0
# 4    8201.0       8305.0       5911.0       5903.0       8402.0
#
#   keterlibatan_vltr  jml_vltr_terlibat  tahun    skema luaran_hki  \
# 0             TIDAK                  0   2019  REGULER  TIDAK ADA
# 1             TIDAK                  0   2019  REGULER  TIDAK ADA
# 2             TIDAK                  0   2019  REGULER  TIDAK ADA
# 3             TIDAK                  0   2019  REGULER  TIDAK ADA
# 4             TIDAK                  0   2019  REGULER  TIDAK ADA
#
#   jenis_luaran_hki potensi_hki luaran_lain jenis_luaran_lain  \
# 0        TIDAK ADA       TIDAK   TIDAK ADA         TIDAK ADA
# 1        TIDAK ADA       TIDAK   TIDAK ADA         TIDAK ADA
# 2        TIDAK ADA       TIDAK   TIDAK ADA         TIDAK ADA
# 3        TIDAK ADA       TIDAK   TIDAK ADA         TIDAK ADA
# 4        TIDAK ADA       TIDAK   TIDAK ADA         TIDAK ADA
#
#   status_luaran_lain
# 0          TIDAK ADA
# 1          TIDAK ADA
# 2          TIDAK ADA
# 3          TIDAK ADA
# 4          TIDAK ADA

# %%
# Cek data yang kosong
df.isna().sum()
# Out:
# id_ketua              0
# id_anggota1           0
# id_anggota2           0
# id_anggota3           0
# id_anggota4           0
# keterlibatan_vltr     0
# jml_vltr_terlibat     0
# tahun                 0
# skema                 0
# luaran_hki            0
# jenis_luaran_hki      0
# potensi_hki           0
# luaran_lain           0
# jenis_luaran_lain     0
# status_luaran_lain    0
# dtype: int64

# %% [markdown]
# TUGAS NO.1
# 1. Buat 5 jenis visualisasi yang dapat dihasilkan dari dataset yang diberikan!

# %%
# Bar Chart Horizontal
df.groupby(['jenis_luaran_lain']).size().plot(
    kind='barh', title='Jenis Iuaran Lain')
# Out:
# <AxesSubplot:title={'center':'Jenis\xa0Iuaran\xa0Lain'}, ylabel='jenis_luaran_lain'>

# %%
# Line Chart
from matplotlib import pyplot as plt


df.groupby(['tahun']).sum().plot(
    kind='line', y='jml_vltr_terlibat', title='Jumlah Volunteer Setiap Tahun', grid=True)

plt.legend(['Jumlah volunteer'])
# Out:
# C:\Users\Tzelginia Noer C\AppData\Local\Temp\ipykernel_18368\3582069047.py:5: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(['tahun']).sum().plot(

# %%
# Pie Chart
# Persentase keterlibatan volunteer pada tim
colors = ['pink', 'steelblue']

df.groupby(['keterlibatan_vltr']).sum().plot(
    kind='pie', y='id_ketua', autopct='%1.0f%%')
# Out:
# C:\Users\Tzelginia Noer C\AppData\Local\Temp\ipykernel_18368\4034230968.py:5: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(['keterlibatan_vltr']).sum().plot(
# <AxesSubplot:ylabel='id_ketua'>

# %%
# Bar Chart Vertikal
df.groupby(['status_luaran_lain']).size().plot(
    kind='bar', title='Status Luaran Lain')
# Out:
# <AxesSubplot:title={'center':'Status\xa0Luaran\xa0Lain'}, xlabel='status_luaran_lain'>

# %%
# Histogram
plt.hist(df['tahun'])
plt.title('Hasil Luaran Kegiatan dari tahun ke tahun', size=16)
plt.xlabel('Tahun', size=15)
plt.ylabel('Jumlah Luaran Hasil Kegiatan', size=15)
# Out:
# Text(0, 0.5, 'Jumlah Luaran Hasil Kegiatan')

# %% [markdown]
# ### Tugas No. 2 & 3
# Lakukan pemilahan data training dan testing yang sesuai dan proporsional dari data tersebut
# Tentukan data validasi

# %%
#Encode label pada beberapa kolom

from sklearn.preprocessing import LabelEncoder
encode = LabelEncoder()
df['keterlibatan_vltr'] = encode.fit_transform(df['keterlibatan_vltr'])
df['skema'] = encode.fit_transform(df['skema'])
df['luaran_hki'] = encode.fit_transform(df['luaran_hki'])
df['jenis_luaran_hki'] = encode.fit_transform(df['jenis_luaran_hki'])
df['potensi_hki'] = encode.fit_transform(df['potensi_hki'])
df['luaran_lain'] = encode.fit_transform(df['luaran_lain'])
df['jenis_luaran_lain'] = encode.fit_transform(df['jenis_luaran_lain'])
df['status_luaran_lain'] = encode.fit_transform(df['status_luaran_lain'])
df.head()
# Out:
#    id_ketua  id_anggota1  id_anggota2  id_anggota3  id_anggota4  \
# 0    7206.0       7214.0       6211.0       8602.0       7801.0
# 1    7214.0       7109.0       8402.0       7903.0       9202.0
# 2    5911.0       8201.0       8701.0       9101.0       9003.0
# 3    8402.0       7702.0       8602.0       8903.0       8903.0
# 4    8201.0       8305.0       5911.0       5903.0       8402.0
#
#    keterlibatan_vltr  jml_vltr_terlibat  tahun  skema  luaran_hki  \
# 0                  0                  0   2019      1           1
# 1                  0                  0   2019      1           1
# 2                  0                  0   2019      1           1
# 3                  0                  0   2019      1           1
# 4                  0                  0   2019      1           1
#
#    jenis_luaran_hki  potensi_hki  luaran_lain  jenis_luaran_lain  \
# 0                 1            2            0                  3
# 1                 1            2            0                  3
# 2                 1            2            0                  3
# 3                 1            2            0                  3
# 4                 1            2            0                  3
#
#    status_luaran_lain
# 0                   1
# 1                   1
# 2                   1
# 3                   1
# 4                   1

# %%
#selesksi fitur
X = df.iloc[:,7:-1]
y = df['keterlibatan_vltr']

X.shape
# Out:
# (85, 7)

# %%
#training dan validasi data

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

X_val, X_unseen, y_val, y_unseen = train_test_split(X_test, y_test, test_size=0.5, random_state=10)

# %% [markdown]
# ### Tugas No. 4
# Terapkan dua jenis metode klasifikasi dan lakukan perbandingan akurasi  dengan wajib melibatkan variabel keterlibatan volunteer sampai variabel luaran-luaran yang dihasilkan!

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

# Sesuaikan dt ke set training
dt = DecisionTreeClassifier()
dt.fit(X_train, y_train)

# Memprediksi label set test
y_pred_dt = dt.predict(X_test)

# Menghitung set accuracy
acc_dt = accuracy_score(y_test, y_pred_dt)
print("Test set accuracy: {:.2f}".format(acc_dt))
print(f"Test set accuracy: {acc_dt}")
# Out:
# Test set accuracy: 0.59
# Test set accuracy: 0.5882352941176471

# %%
from sklearn.ensemble import RandomForestClassifier

# Sesuaikan rf ke set training
rf = RandomForestClassifier(n_estimators=20, random_state=5)
rf.fit(X_train, y_train)

# Memprediksi label set test
y_pred_rf = rf.predict(X_test)

# Menghitung set accuracy
acc_rf = accuracy_score(y_test, y_pred_rf)
print("Test set accuracy: {:.2f}".format(acc_rf))
print(f"Test set accuracy: {acc_rf}")
# Out:
# Test set accuracy: 0.59
# Test set accuracy: 0.5882352941176471

# %% [markdown]
# ### Tugas No.5
# Terapkan sebuah metode prediksi (berdasarkan tahun, misal: jumlah kegiatan pada tahun tertentu sebagai x dan jumlah  luaran sebagai y) serta hitung akurasinya dengan wajib melibatkan variabel keterlibatan volunteer sampai variabel luaran-luaran yang dihasilkan!

# %%
#selesksi fitur
A= df[['jml_vltr_terlibat']]
b = df['luaran_hki']

#training data
A_train, A_test, b_train, b_test = train_test_split(A, b, test_size=0.3, random_state=3)

# %%
from sklearn.tree import DecisionTreeRegressor

#inissiasi DT
dt = DecisionTreeRegressor(max_depth=8,min_samples_leaf=0.13,random_state=3)
dt.fit(A_train,b_train)

#fit ke dalam training set
DecisionTreeRegressor(max_depth=8,min_samples_leaf=0.13,random_state=3)
# Out:
# DecisionTreeRegressor(max_depth=8, min_samples_leaf=0.13, random_state=3)

# %%
from sklearn.metrics import mean_squared_error

#compute b_pred
b_pred = dt.predict(A_test)

#compute mse_dt
mse_dt = mean_squared_error(b_test,b_pred)

#compute rmse_dt
rmse_dt = mse_dt ** (1/2)

#Print rmse_dt
print("Hasil MSE : {:.2f}".format(rmse_dt))
# Out:
# Hasil MSE : 0.29

# %% [markdown]
# ### Tugas No.6
#  Buat Confusion Matrix dan ROC berdasarkan klasifikasi yang diterapkan pada nomor 4!

# %%
#confusion matrix Decission Tree
from sklearn.metrics import confusion_matrix
cm_dt= confusion_matrix(y_test, y_pred_dt)

import seaborn as sns 
f, ax =plt.subplots(figsize = (5,5))

sns.heatmap(cm_dt,annot = True, linewidths= 0.5, linecolor="red", fmt=".0f", ax=ax)
plt.xlabel("y_pred_dt")
plt.ylabel("y_test")
plt.show()

# %%
#confusion matrix Random Forest
cm_rf= confusion_matrix(y_test, y_pred_rf)

import seaborn as sns 
f, ax =plt.subplots(figsize = (5,5))

sns.heatmap(cm_rf,annot = True, linewidths= 0.5, linecolor="blue", fmt=".0f", ax=ax)
plt.xlabel("y_pred_rf")
plt.ylabel("y_test")
plt.show()

# %%
from sklearn.metrics import roc_curve, roc_auc_score

clf_tree = DecisionTreeClassifier()
clf_rand = RandomForestClassifier()

clf_tree.fit(X_train, y_train)
clf_rand.fit(X_train, y_train)

y_score1 = clf_tree.predict_proba(X_test)[:,1]
y_score2 = clf_rand.predict_proba(X_test)[:,1]

false_positive_rate1, true_positive_rate1, threshold1 = roc_curve(y_test, y_score1)
false_positive_rate2, true_positive_rate2, threshold2 = roc_curve(y_test, y_score2)

print('roc_auc_score for DecisionTree: ', roc_auc_score(y_test, y_score1))
print('roc_auc_score for Random Forest: ', roc_auc_score(y_test, y_score2))
# Out:
# roc_auc_score for DecisionTree:  0.5
# roc_auc_score for Random Forest:  0.4305555555555556

# %%
plt.subplots(1, figsize=(10,10))
plt.title('Receiver Operating Characteristic - DecisionTree')
plt.plot(false_positive_rate1, true_positive_rate1)
plt.plot([0, 1], ls="--")
plt.plot([0, 0], [1, 0] , c=".7"), plt.plot([1, 1] , c=".7")
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

plt.subplots(1, figsize=(10,10))
plt.title('Receiver Operating Characteristic - Random Forest')
plt.plot(false_positive_rate2, true_positive_rate2)
plt.plot([0, 1], ls="--")
plt.plot([0, 0], [1, 0] , c=".7"), plt.plot([1, 1] , c=".7")
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %% [markdown]
# ### Tugas No.7
# Lakukan hyperparameter tunning berdasarkan jawaban nomor 2, 3, dan 4 menggunakan metode Grid Search, Random Search, dan Exhausive Search

# %%
# GridSearch menggunakan Decission Tree
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RepeatedKFold

#inisiasi repeated k-fold
cv = RepeatedKFold(n_splits=4, n_repeats=3, random_state=42)

# Definisikan hyperparameter yang akan digunakan
params = {
    'criterion' : ['gini', 'entropy', 'log_loss'],
    'max_depth' : list(range(5,11))
}

# inisiasi grid berdasarkan nilai repeated k-fold dan hyperparameter
grid = GridSearchCV(clf_tree, param_grid=params, cv=cv)

# Fit / latih berdasarkan grid
# %timeit grid.fit(X,y)

# Evaluasi dengan score
score = grid.score(X,y)

print(f'Hasil evaluasi: {score}')
print(f'Konfigurasi hyperparameter : {grid.best_params_}')
# Out:
# 526 ms ± 37.7 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# Hasil evaluasi: 0.7529411764705882
# Konfigurasi hyperparameter : {'criterion': 'entropy', 'max_depth': 8}

# %%
# Random search menggunakan Decission Tree
from sklearn.model_selection import RandomizedSearchCV

# Definisikan hyperparameter yang akan digunakan
params = {
    'criterion' : ['gini', 'entropy'],
    'max_depth' : list(range(5,11))
}

# inisiasi grid berdasarkan nilai repeated k-fold dan hyperparameter
random = RandomizedSearchCV(clf_tree, params, cv=cv)

# Fit / latih berdasarkan random
# %timeit random.fit(X,y)

# Evaluasi dengan score
score = random.score(X,y)

print(f'Hasil evaluasi: {score}')
print(f'Konfigurasi hyperparameter : {random.best_params_}')
# Out:
# 279 ms ± 9.1 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# Hasil evaluasi: 0.7529411764705882
# Konfigurasi hyperparameter : {'max_depth': 8, 'criterion': 'entropy'}

# %%
# Exhausive Search menggunakan Decission Tree
model_dt_manual = DecisionTreeClassifier(criterion='entropy', max_depth=8, max_leaf_nodes=10)

# %timeit model_dt_manual.fit(X, y)

# Evaluasi dengan score
score = model_dt_manual.score(X,y)

print(f'Hasil evaluasi: {score}')
# Out:
# 863 µs ± 54.4 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# Hasil evaluasi: 0.7411764705882353

# %%
# Grid Search menggunakan Random Forest
# Definisikan hyperparameter yang akan digunakan
params_rf = {
    'n_estimators': [5,20,50,70],
    'max_depth': [int(x) for x in np.linspace(10, 120, num = 12)],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'bootstrap': [True, False]
}

# inisiasi grid berdasarkan nilai repeated k-fold dan hyperparameter
grid_rf = GridSearchCV(clf_rand, param_grid=params_rf)

# Fit / latih berdasarkan grid
# %timeit grid_rf.fit(X,y)

# Evaluasi dengan score
score_rf = grid_rf.score(X,y)

print(f'Hasil evaluasi: {score_rf}')
print(f'Konfigurasi hyperparameter : {grid_rf.best_params_}')
# Out:
# 2min 34s ± 27.6 s per loop (mean ± std. dev. of 7 runs, 1 loop each)
# Hasil evaluasi: 0.7176470588235294
# Konfigurasi hyperparameter : {'bootstrap': False, 'max_depth': 50, 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 5}

# %%
# Random Search menggunakan Random Forest
# Definisikan hyperparameter yang akan digunakan
params_rf = {
    'n_estimators': [5,20,50,70],
    'max_depth': [int(x) for x in np.linspace(10, 120, num = 12)],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'bootstrap': [True, False]
}

# inisiasi grid berdasarkan nilai repeated k-fold dan hyperparameter
random_rf = RandomizedSearchCV(clf_rand, params_rf)

# Fit / latih berdasarkan grid
# %timeit random_rf.fit(X,y)

# Evaluasi dengan score
score_rf = random_rf.score(X,y)

print(f'Hasil evaluasi: {score_rf}')
print(f'Konfigurasi hyperparameter : {random_rf.best_params_}')
# Out:
# 1.67 s ± 406 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# Hasil evaluasi: 0.7058823529411765
# Konfigurasi hyperparameter : {'n_estimators': 5, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_depth': 20, 'bootstrap': False}

# %%
# Exhausive Search menggunakan Random Forest
model_rf_manual = RandomForestClassifier(n_estimators=50, min_samples_split=5, min_samples_leaf=4, max_depth=20, bootstrap=True)
# %timeit model_rf_manual.fit(X, y)

# Evaluasi dengan score
score = model_rf_manual.score(X,y)

print(f'Hasil evaluasi: {score}')
# Out:
# 44.5 ms ± 7.32 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# Hasil evaluasi: 0.7058823529411765

# %% [markdown]
# ### Tugas No.8
# Tambahkan visualisasi berdasarkan nomor 4 dan 5 (masing-masing nomor minimal satu visualisasi

# %%
# visualisasi histogram untuk decision tree
plt.hist(y_pred_dt)
plt.title('Histogram For Decision Tree', size=16)
# Out:
# Text(0.5, 1.0, 'Histogram For Decision Tree')

# %%
# Visualisasi line chart untuk random forest
#Line Chart
plt.figure(figsize=(10,5))
plt.plot(y_test, y_pred_rf,'g--d')
plt.legend(['Line Chart For Random Forest'])
plt.xlabel("Factual Data")
plt.ylabel("Predicted Data")
plt.show()

# %%
# Visualisasi Nomer 5 menggunakan scatter plot
import matplotlib.pyplot as plt
plt.scatter(A_train, b_train, color='red')
plt.scatter(b_test, dt.predict(A_test), color='purple')
plt.xlabel("Jumlah Volunteer Terlibat")
plt.ylabel("Luaran HKI")
plt.title("Prediksi Hasil Luaran VS Jumlah Volunteer Terlibat")
plt.show()
